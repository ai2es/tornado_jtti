# %%
import os, glob

import xarray as xr

# %%
engine = 'netcdf4'
filepath = "tornado/wofs-preds-2023/20230511/1830/ENS_MEM_1/wrfwof_d01_2023-05-11_19_55_00_predictions.nc"
preds = xr.open_dataset(filepath, engine=engine, decode_times=False, decode_coords=True)
preds
# Out:
# <xarray.Dataset> Size: 75MB
# Dimensions:              (Time: 1, south_north: 300, west_east: 300,
#                           bottom_top_stag: 51, bottom_top: 50,
#                           south_north_stag: 301, west_east_stag: 301)
# Coordinates:
#     XLAT                 (Time, south_north, west_east) float32 360kB ...
#     XLONG                (Time, south_north, west_east) float32 360kB ...
#   * Time                 (Time) int64 8B 705527700
#     XTIME                (Time) float32 4B ...
# Dimensions without coordinates: south_north, west_east, bottom_top_stag,
#                                 bottom_top, south_north_stag, west_east_stag
# Data variables:
#     ML_PREDICTED_TOR     (Time, south_north, west_east) float64 720kB ...
#     COMPOSITE_REFL_10CM  (Time, south_north, west_east) float32 360kB ...
#     W                    (Time, bottom_top_stag, south_north, west_east) float32 18MB ...
#     W_UP_MAX             (Time, south_north, west_east) float32 360kB ...
# ...

# %%
filepath_wofs = "tornado/wofs-preds-2023-init/2023/20230511/202305111500/ENS_MEM_18/wrfinput_d01_predictions.nc"
filepath_wofs = "tornado/wofs-preds-2023-init/2023/202305111500/ENS_MEM_18/wrfinput_d01_predictions.nc"
wofs = xr.open_dataset(filepath_wofs, engine=engine, decode_times=False, decode_coords=True)
wofs
# Out:
# <xarray.Dataset> Size: 150MB
# Dimensions:              (Time: 1, south_north: 300, west_east: 300,
#                           bottom_top_stag: 51, bottom_top: 50,
#                           south_north_stag: 301, west_east_stag: 301)
# Coordinates:
#     XLAT                 (Time, south_north, west_east) float32 360kB ...
#     XLONG                (Time, south_north, west_east) float32 360kB ...
#   * Time                 (Time) int64 8B 705510000
#     XTIME                (Time) float32 4B ...
#     XLAT_U               (Time, south_north, west_east_stag) float32 361kB ...
#     XLONG_U              (Time, south_north, west_east_stag) float32 361kB ...
#     XLAT_V               (Time, south_north_stag, west_east) float32 361kB ...
#     XLONG_V              (Time, south_north_stag, west_east) float32 361kB ...
# Dimensions without coordinates: south_north, west_east, bottom_top_stag,
#                                 bottom_top, south_north_stag, west_east_stag
# ...

# %%
preds_dir = "/glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/"
dates = [i[-8:] for i in glob.glob(preds_dir+'2023****', recursive=True)]
dates
# Out:
# ['20230512', '20230511']

# %%
init_times = [i[-4:] for i in glob.glob(preds_dir+dates[1]+'/****', recursive=True)]

for init_time in init_times:
    if init_time.startswith('0'):
        print(init_time)
# Out:
# 0100
# 0230
# 0000
# 0300
# 0130
# 0200
# 0030

# %%
init_times = [i[-4:] for i in glob.glob(preds_dir+dates[1]+'/****', recursive=True)]
init_times
# Out:
# ['2230', '1900', '2030', '0100', '1830', '2000', '2300', '0230', '2130', '1800', '0000', '1930', '0300', '1730', '2200', '0130', '1700', '2330', '0200', '2100', '0030']

# %%
init_dir+date
# Out:
# 'tornado/wofs-preds-2023-init/2023/20230511/20230511'

# %%
init_dir = f"tornado/wofs-preds-2023-init/2023/{date}/"
wofs_init_times = [i[-10:] for i in glob.glob(init_dir+'/*', recursive=True)]
print(wofs_init_times)
# Out:
# ['2305112200', '2305120000', '2305112300', '2305111700', '2305112000', '2305111600', '2305120100', '2305112030', '2305120300', '2305111730', '2305111630', '2305120230', '2305120030', '2305112230', '2305120130', '2305120200', '2305112100', '2305111900', '2305112330', '2305111830', '2305111800', '2305111500', '2305112130', '2305111930', '2305111530']

# %%
wofs_init_times.index(init_time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 wofs_init_times.index(init_time)
#
# ValueError: '0030' is not in list

# %%
list(filter(lambda x: x.endswith(init_time), wofs_init_times))
# Out:
# ['2305120030']

# %%
dates
# Out:
# ['20230512', '20230511']

# %%
init_times
# Out:
# ['2230',
#  '1900',
#  '2030',
#  '0100',
#  '1830',
#  '2000',
#  '2300',
#  '0230',
#  '2130',
#  '1800',
#  '0000',
#  '1930',
#  '0300',
#  '1730',
#  '2200',
#  '0130',
#  '1700',
#  '2330',
#  '0200',
#  '2100',
#  '0030']

# %%
preds_dir = "/glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/"
init_dir = "tornado/wofs-preds-2023-init/2023/"
dates = [i[-8:] for i in glob.glob(preds_dir+'2023****', recursive=True)]

for date in dates[1:]:

    init_times = [i[-4:] for i in glob.glob(preds_dir+date+'/****', recursive=True)]
    wofs_init_times = [i[-12:] for i in glob.glob(init_dir+date+'/*', recursive=True)]

    for init_time in init_times:
        if init_time.startswith('0'):
            wofs_init_time = list(filter(lambda x: x.endswith(init_time), wofs_init_times))[0]
        else:
            wofs_init_time = date+init_time
        
        for ens in range(1, 19):
            filepath_wofs = init_dir + f"{date}/{wofs_init_time}/ENS_MEM_{ens}/wrfinput_d01_predictions.nc"
            print(filepath_wofs)
            wofs = xr.open_dataset(filepath_wofs, engine=engine, decode_times=False, decode_coords=True)
    
            files = glob.glob(preds_dir+f"{date}/{init_time}/ENS_MEM_{ens}/**.nc", recursive=True)
    
            for file in files:
                print(file)
                preds = xr.open_dataset(file, engine=engine, decode_times=False, decode_coords=True)
                preds["HGT"] = (['Time', 'south_north', 'west_east'],  wofs["HGT"].data)
    
                savepath = file.replace('wofs-preds-2023', 'wofs-preds-2023-hgt')
                os.makedirs(savepath.split('wrfwof')[0], exist_ok=True)
    
                encoding_vars = [k for k in preds.variables.keys() if k not in ["Times", "Time"]]
                encoding = {var: {"zlib":True, "complevel":4, "least_significant_digit":2} for var in encoding_vars}
                encoding["ML_PREDICTED_TOR"]['least_significant_digit'] = 3
                preds.to_netcdf(savepath, encoding=encoding)
# Out:
# tornado/wofs-preds-2023-init/2023/20230511/202305112230/ENS_MEM_1/wrfinput_d01_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-12_01_20_00_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-11_23_05_00_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-12_01_10_00_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-11_22_30_00_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-12_00_30_00_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-12_00_45_00_predictions.nc
# /glade/work/ggantos/tornado_jtti/tornado/wofs-preds-2023/20230511/2230/ENS_MEM_1/wrfwof_d01_2023-05-11_23_15_00_predictions.nc
# ...

# %% [markdown]
# https://github.com/ai2es/tornado_jtti/blob/main/scripts/process_gridrad_scripts/Step_01.sh
# https://github.com/ai2es/tornado_jtti/blob/main/lydia_scripts/wofs_raw_predictions.sh
# https://github.com/ai2es/tornado_jtti/blob/main/lydia_scripts/wofs_ensemble_predictions.sh

# %%
model_path = "tor_unet_sample50_50_classweightsNone_hyper"

# %% [markdown]
# oscer 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
